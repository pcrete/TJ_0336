# %% [markdown]
# # Team Name: **Kubernetes**, Team ID: **336**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.interactiveshell import InteractiveShell
from glob import glob

InteractiveShell.ast_node_interactivity = 'all'

files = glob('*_submit.csv')
files.sort()

tmps = [
    pd.read_csv('./submissions/013_submit.csv', index_col='id'),
    pd.read_csv('./submissions/010_submit.csv', index_col='id'),
    pd.read_csv('./submissions/009_submit.csv', index_col='id'),
    pd.read_csv('./submissions/007_submit.csv', index_col='id')
]

df = pd.concat(tmps, axis=0)
df = df.reset_index()
df = df.groupby('id').mean()
df
# Out:
#           class0    class1    class2    class3    class4        class5  \
# id
# 100001  0.001492  0.001402  0.588861  0.248628  0.148157  7.957516e-07
# 100002  0.002906  0.001363  0.163227  0.019030  0.708678  3.279508e-06
# 100003  0.002787  0.011593  0.518657  0.133644  0.102288  2.142113e-04
# 100004  0.009680  0.003103  0.079392  0.715077  0.016112  2.823547e-07
# 100005  0.006392  0.005502  0.106117  0.036562  0.059508  8.916845e-05
# ...          ...       ...       ...       ...       ...           ...
# 153236  0.003979  0.001236  0.037721  0.815686  0.014128  7.875620e-07
# 153237  0.004575  0.143319  0.147759  0.078265  0.427755  8.104336e-05
# 153238  0.001472  0.006589  0.057253  0.157879  0.729414  2.469328e-06
# 153239  0.010091  0.022804  0.178462  0.373854  0.215568  9.655879e-06
# 153240  0.001176  0.137137  0.319067  0.043260  0.351487  7.001103e-05
#
#           class6    class7    class8    class9   class10   class11   class12
# id
# ...

# %%
y_submit = pd.read_csv('data/004_test.csv', index_col='id')

# %%
y_submit = y_submit.join(df)
y_submit
# Out:
#           class0    class1    class2    class3    class4        class5  \
# id
# 151807  0.004687  0.006146  0.209161  0.028322  0.065225  6.624723e-05
# 118131  0.001209  0.011702  0.710390  0.139657  0.066024  1.401692e-05
# 110921  0.003285  0.026280  0.114774  0.741698  0.010133  2.027017e-05
# 105149  0.002495  0.089779  0.210418  0.296991  0.228552  1.345366e-05
# 143868  0.003549  0.001537  0.021116  0.006355  0.015858  7.106569e-06
# ...          ...       ...       ...       ...       ...           ...
# 146316  0.003371  0.013538  0.081080  0.662899  0.151865  1.979775e-06
# 121816  0.002204  0.001412  0.128508  0.026309  0.339618  1.282079e-05
# 106217  0.000514  0.021279  0.023420  0.100774  0.802497  2.490396e-06
# 103515  0.014520  0.009334  0.106974  0.085045  0.245304  7.311831e-06
# 113723  0.001609  0.000125  0.030592  0.024441  0.007307  7.054037e-07
#
#           class6    class7    class8    class9   class10   class11   class12
# id
# ...

# %%
y_submit.to_csv('014_submit.csv')
