# %% [markdown]
# # **031:** Train-Test Split for **all** features
#
# ## 1. Input:
#
# ```
# ./data/300_features.csv
# ```
#
# ## 2. Output:
# ```
# ./data/400_X_submit.csv
# ./data/400_X_train.csv
# ./data/400_X_test.csv
#
# ./data/400_y_train.csv
# ./data/400_y_test.csv
# ```

# %%
from collections import Counter
from IPython.core.interactiveshell import InteractiveShell
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

InteractiveShell.ast_node_interactivity = 'all'

df_features = pd.read_csv('./data/330_features_txn.csv')
df_train = pd.read_csv('./data/003_train.csv')
df_test  = pd.read_csv('./data/004_test.csv')

# %%
train_set = pd.merge(df_train, df_features, how='left', on='id')
X_submit  = pd.merge(df_test, df_features, how='left', on='id')

train_set.set_index('id', inplace=True)
X_submit.set_index('id', inplace=True)

X = train_set.drop('label', axis=1)
y = train_set[['label']]

X.head()
# Out:
#           c7_n7     c5__0     c5__1     c5__2     c5__3     c5__4     c5__5  \
# id
# 84531  1.270320  0.764710 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 25895 -0.219151  1.255413 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 71109  0.437538  1.224655 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 64666  0.766535 -0.589456 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 91813  0.175748  0.000000 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
#
#           c5__6     c5__7     c5__8  ...    n6_min    n7_min  n4_median  \
# id                                   ...
# 84531 -5.199338 -5.199338 -5.199338  ... -5.199338  0.386972   0.311322
# 25895 -5.199338 -5.199338 -5.199338  ... -5.199338  0.113460  -0.430727
# 71109 -5.199338 -5.199338 -5.199338  ... -5.199338  0.544594  -0.764710
# 64666 -5.199338 -5.199338 -5.199338  ... -5.199338  0.425127   0.139710
# 91813 -5.199338 -5.199338 -5.199338  ... -5.199338 -0.911522   0.793734
#
#        n5_median  n6_median  n7_median    n4_std    n5_std    n6_std    n7_std
# id
# 84531   0.919136   0.170351   0.165083  0.416452  1.260004 -0.103069 -5.199338
# 25895  -1.220640  -0.139710  -0.119209 -0.627521 -0.246973  0.076762 -5.199338
# 71109  -1.220640  -0.128001   0.322287 -0.122000  0.058722 -0.542718 -5.199338
# 64666  -0.139710   0.953617   0.202001 -0.135418  1.124756 -0.081915 -5.199338
# 91813   0.535083   0.011605  -1.287592  1.225630  0.828241 -0.421037 -5.199338
#
# [5 rows x 311 columns]

# %% [markdown]
# ## Load previous train-test splits to maintain indexes

# %%
y_train = pd.read_csv('./data/410_y_train.csv')
y_test  = pd.read_csv('./data/410_y_test.csv')

# %%
X_train = X.loc[y_train['id'].values].copy()
X_train.head()
y_train.head()
# Out:
#           c7_n7     c5__0     c5__1     c5__2     c5__3     c5__4     c5__5  \
# id
# 19849 -0.080881  0.139710  1.236227 -5.199338 -5.199338 -5.199338 -5.199338
# 34583 -0.373794  0.799083 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 86660  0.400765  1.168949 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 73039  0.883244  0.703922 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 38589  0.514574  0.764710  1.236227 -5.199338 -5.199338 -5.199338  1.238343
#
#           c5__6     c5__7     c5__8  ...    n6_min    n7_min  n4_median  \
# id                                   ...
# 19849 -5.199338 -5.199338 -5.199338  ... -5.199338 -1.731664  -0.764710
# 34583 -5.199338 -5.199338 -5.199338  ... -5.199338 -1.118311  -0.430727
# 86660 -5.199338 -5.199338 -5.199338  ... -5.199338  1.233387  -0.430727
# 73039 -5.199338 -5.199338 -5.199338  ... -5.199338 -0.923867  -0.508488
# 38589 -5.199338 -5.199338 -5.199338  ... -5.199338 -1.187193   0.589456
#
#        n5_median  n6_median  n7_median    n4_std    n5_std    n6_std    n7_std
# id
# 19849   0.139710   0.005802  -0.686252 -0.425349 -0.687600  1.097375  0.570668
# 34583   0.139710  -5.199338  -1.468851 -0.938500 -0.848506 -1.293418  1.312930
# 86660  -1.382994   0.320232   1.164030 -0.089540  0.074726  1.189175 -5.199338
# 73039   1.225627  -0.499851  -1.298211 -0.818417  1.486860  0.660232 -5.199338
# 38589   0.430727   0.695743  -1.530862  0.916116  1.002813  0.265945  0.928437
#
# [5 rows x 311 columns]
#       id  label
# 0  19849      9
# 1  34583      2
# 2  86660      3
# 3  73039     12
# 4  38589      4

# %%
X_test  = X.loc[y_test['id'].values].copy()
X_test.head()
y_test.head()
# Out:
#           c7_n7     c5__0     c5__1     c5__2     c5__3     c5__4     c5__5  \
# id
# 11020 -0.439758 -0.139710 -5.199338 -5.199338 -5.199338 -5.199338  1.220640
# 78932  0.383094  0.908458 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 66518  1.392204  1.245029 -5.199338 -5.199338 -5.199338 -5.199338 -5.199338
# 61221  0.927966  0.703922 -5.199338 -5.199338 -5.199338 -5.199338  1.220640
# 48750 -0.293778 -0.139710 -5.199338 -5.199338 -5.199338 -5.199338  1.220640
#
#           c5__6     c5__7     c5__8  ...    n6_min    n7_min  n4_median  \
# id                                   ...
# 11020 -5.199338 -5.199338 -5.199338  ... -5.199338 -1.369793  -0.764710
# 78932 -5.199338 -5.199338 -5.199338  ... -5.199338 -1.009516   0.823442
# 66518 -5.199338 -5.199338 -5.199338  ... -5.199338 -1.404632  -1.347629
# 61221 -5.199338 -5.199338 -5.199338  ... -5.199338 -2.097518  -1.220640
# 48750 -5.199338 -5.199338 -5.199338  ... -5.199338  0.833391  -1.220640
#
#        n5_median  n6_median  n7_median    n4_std    n5_std    n6_std    n7_std
# id
# 11020  -0.330873  -0.139710  -1.697873  0.959190 -0.500311 -0.242148 -5.199338
# 78932  -0.330873   0.113389   0.456516  0.352517 -0.607897 -0.383644  1.248601
# 66518   0.806850   0.092972   0.720235  0.470974  1.244705 -0.700137  1.263732
# 61221  -0.330873   0.764710  -0.681898  0.042589 -0.324048  0.384235  0.732251
# 48750  -0.234219  -5.199338   0.629719  0.412459 -0.722340 -0.633366 -5.199338
#
# [5 rows x 311 columns]
#       id  label
# 0  11020     12
# 1  78932      4
# 2  66518      3
# 3  61221      4
# 4  48750      2

# %%
X.shape
X_submit.shape
X_train.shape
X_test.shape
# Out:
# (100000, 311)
# (53240, 311)
# (80000, 311)
# (20000, 311)

# %%
X_submit.to_csv('./data/430_X_submit.csv', index=True)
X_train.to_csv('./data/430_X_train.csv', index=True)
X_test.to_csv('./data/430_X_test.csv', index=True)
